# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
data=load_wine()

# %%
df=pd.DataFrame(data=data.data,columns=data.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df['target']=data.target
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
#Data Cleaning
df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
df['target'].unique()
# Out:
# array([0, 1, 2])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
#NO Null Values in the Datasets

# %%
#Distribution of each plots
for i in df.columns:
    sns.displot(df[i],kde=True )

# %%
# Independent and Dependent Features
x=df.iloc[:,:-1]  #Independent Features
y=df['target']#Dependent Features

# %%
x
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Name: target, Length: 178, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=11)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((124, 13), (54, 13), (124,), (54,))

# %%
Numerical_Features=x.select_dtypes(exclude='object').columns
print(Numerical_Features)
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
#Data Transformer

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

# %%
columnstransformer=ColumnTransformer(
    transformers=[('standard',StandardScaler(),Numerical_Features)],
    remainder='drop'
)

x_train=columnstransformer.fit_transform(x_train)
x_test=columnstransformer.transform(x_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
y_tra_pre=ada.predict(x_train)
y_pred=ada.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %%
model={
    "adaboost classifier":AdaBoostClassifier(),
    "DecisionTree Classifier":DecisionTreeClassifier(),
    "KNeghibors":KNeighborsClassifier(),
    "Logistic Regression":LogisticRegression(),
    "RandomForest":RandomForestClassifier(),
    "NaviesBayes_GaussianNB":GaussianNB(),
    "SupportVectorCla"
}

for i in range(len(list(model))):
    models=list(model.values())[i]
    
    models.fit(x_train,y_train)
    y_tra_pre=models.predict(x_train)
    y_pred=ada.predict(x_test)
    
    print('-'*45)
    print(list(model.keys())[i])
    print('-'*45)
    

    train_acc=accuracy_score(y_train,y_tra_pre)
    train_pre=precision_score(y_train,y_tra_pre,average='micro')
    train_rec=recall_score(y_train,y_tra_pre,average='micro')
    train_f1=f1_score(y_train,y_tra_pre,average='micro')

    print('training Accuracy :',train_acc)
    print('training Precision:',train_pre)
    print('training Recall:',train_rec)
    print('training f1:',train_f1)

    test_acc=accuracy_score(y_test,y_pred)
    test_pre=precision_score(y_test,y_pred,average='micro')
    test_rec=recall_score(y_test,y_pred,average='micro')
    test_f1=f1_score(y_test,y_pred,average='micro')

    print("Testing Accuracy:",test_acc)
    print("Testing Precision ",test_pre)
    print("Testing Rec",test_rec)
    print("Testing f1",test_f1)
# Out:
# ---------------------------------------------
# adaboost classifier
# ---------------------------------------------
# training Accuracy : 1.0
# training Precision: 1.0
# training Recall: 1.0
# training f1: 1.0
# Testing Accuracy: 0.9814814814814815
# Testing Precision  0.9814814814814815
# Testing Rec 0.9814814814814815
# Testing f1 0.9814814814814815
# ---------------------------------------------
# DecisionTree Classifier
# ---------------------------------------------
# training Accuracy : 1.0
# training Precision: 1.0
# training Recall: 1.0
# training f1: 1.0
# Testing Accuracy: 0.9814814814814815
# Testing Precision  0.9814814814814815
# Testing Rec 0.9814814814814815
# Testing f1 0.9814814814814815
# ---------------------------------------------
# KNeghibors
# ---------------------------------------------
# training Accuracy : 0.9758064516129032
# training Precision: 0.9758064516129032
# training Recall: 0.9758064516129032
# training f1: 0.9758064516129032
# ...

# %%
print("Precision Score : ",precision_score(y_test, y_pred, 
                                           pos_label='positive',
                                           average='micro'))
print("Recall Score : ",recall_score(y_test, y_pred, 
                                           pos_label='positive',
                                           average='micro'))
# Out:
# Precision Score :  0.9814814814814815
# Recall Score :  0.9814814814814815

# %%
model={
    "ada":AdaBoostClassifier()
}
for i in range(len(list(model))):
    models=list(model.values())[i]
    
    models.fit(x_train,y_train)
    y_tra_pre=ada.predict(x_train)
    y_pred=ada.predict(x_test)

# %%
# Out:
# array([2, 0, 1, 0, 0, 0, 1, 1, 1, 0, 2, 1, 0, 0, 1, 1, 0, 2, 1, 1, 0, 2,
#        0, 0, 0, 1, 0, 2, 1, 0, 1, 1, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 0, 1,
#        1, 0, 1, 0, 0, 2, 1, 1, 2, 1])
