# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from collections import Counter
from sklearn.datasets import make_classification

# %%
#imbalanced dataset
x,y=make_classification(n_samples=10000,n_features=2,n_redundant=0,n_clusters_per_class=1,random_state=42,weights=[0.99])

# %% [markdown]
# # n_samples=100,
#     n_features=20,
#     *,
#     n_informative=2,
#     n_redundant=2,
#     n_repeated=0,
#     n_classes=2,
#     n_clusters_per_class=2,
#     weights=None,
#     flip_y=0.01,
#     class_sep=1.0,
#     hypercube=True,
#     shift=0.0,
#     scale=1.0,
#     shuffle=True,
#     random_state=None,

# %%
Counter(y)
# Out:
# Counter({0: 9859, 1: 141})

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((7500, 2), (2500, 2), (7500,), (2500,))

# %%
class_weights=[{0:x,1:w} for x in [1,10,50,100] for w in [1,10,50,100]]

# %%
class_weights
# Out:
# [{0: 1, 1: 1},
#  {0: 1, 1: 10},
#  {0: 1, 1: 50},
#  {0: 1, 1: 100},
#  {0: 10, 1: 1},
#  {0: 10, 1: 10},
#  {0: 10, 1: 50},
#  {0: 10, 1: 100},
#  {0: 50, 1: 1},
#  {0: 50, 1: 10},
#  {0: 50, 1: 50},
#  {0: 50, 1: 100},
#  {0: 100, 1: 1},
#  {0: 100, 1: 10},
#  {0: 100, 1: 50},
#  {0: 100, 1: 100}]

# %%
max_iter=[100,200,500,1000]

# %%
#Hyper parameter training
from sklearn.linear_model import LogisticRegression
regress=LogisticRegression()
c_values=[0.1,1,10,0.01]
penalty =['l1', 'l2', 'elasticnet']
solver= ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
class_weight=[{0:x,1:w}for x in [1,10,50,100]for w in [1,10,50,100]]

# %%
params=dict(penalty=penalty,solver=solver,class_weight=class_weight,C=c_values)

# %%
params
# Out:
# {'penalty': ['l1', 'l2', 'elasticnet'],
#  'solver': ['lbfgs',
#   'liblinear',
#   'newton-cg',
#   'newton-cholesky',
#   'sag',
#   'saga'],
#  'class_weight': [{0: 1, 1: 1},
#   {0: 1, 1: 10},
#   {0: 1, 1: 50},
#   {0: 1, 1: 100},
#   {0: 10, 1: 1},
#   {0: 10, 1: 10},
#   {0: 10, 1: 50},
#   {0: 10, 1: 100},
#   {0: 50, 1: 1},
#   {0: 50, 1: 10},
#   {0: 50, 1: 50},
#   {0: 50, 1: 100},
#   {0: 100, 1: 1},
#   {0: 100, 1: 10},
#   {0: 100, 1: 50},
#   {0: 100, 1: 100}],
#  'C': [0.1, 1, 10, 0.01]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
grid1=GridSearchCV(estimator=model,param_grid=params,cv=cv,scoring='accuracy')

# %%
model=LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
grid1.fit(x_train,y_train)
# Out:
# C:\Users\kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\kumar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
# ...

# %%
import warnings

# Suppress warnings in a specific block1
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # Your code that generates warnings here

# %%
grid1.best_params_
# Out:
# {'C': 0.1,
#  'class_weight': {0: 1, 1: 10},
#  'penalty': 'l1',
#  'solver': 'liblinear'}

# %%
y_predict=grid1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
score=accuracy_score(y_test,y_predict)
print(score)
confusion=confusion_matrix(y_test,y_predict)
print(confusion)
print(classification_report(y_test,y_predict))
# Out:
# 0.994
# [[2456    1]
#  [  14   29]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2457
#            1       0.97      0.67      0.79        43
#
#     accuracy                           0.99      2500
#    macro avg       0.98      0.84      0.90      2500
# weighted avg       0.99      0.99      0.99      2500
